# %% [markdown]
# # Spelling Check in Python
# This notebook demonstrates the use of Python packages to do spelling check/autocorrect. These packages include:
#  - `contextualSpellCheck`
#  - `autocorrect`
#  - `textblob`
#
# Each of these packages can be pip installed via:
#  - `pip install contextualSpellCheck`
#  - `pip install autocorrect`
#  - `pip install textblob`
#      - `textblob` requires the additional code: `python -m textblob.download_corpora` (worked on INL network for me)

# %% [markdown]
# ## contextualSpellCheck
# This package is used with spaCy in a spaCy pipeline. The focus is on Out of Vocabulary word or non-word error correction using the BERT model. It attempts to use the context when correcting spelling errors. It looks like there is development activity on this package.
#
# There are two ways of including `contextualSpellCheck` in a spaCy pipeline. This package can check spelling, however, an additional step needs to be performed if the tokens should reflect the spell checking.
#
# See also:
#
# https://github.com/R1j1t/contextualSpellCheck

# %% [markdown]
# ### Load contextualSpellCheck in a spaCy pipeline

# %%
import contextualSpellCheck
import spacy
nlp = spacy.load("en_core_web_sm")
print(f"nlp.pipe_names before adding contextualSpellCheck: {nlp.pipe_names}")
contextualSpellCheck.add_to_pipe(nlp)
print(f"\nnlp.pipe_names after  adding contextualSpellCheck: {nlp.pipe_names}")
doc = nlp("Income was $9.4 milion compared to the prior year of $2.7 milion")
print(f"\ncontextualSpellCheck added as extension: {doc._.contextual_spellCheck}")
print(f"\nspell check performed: {doc._.performed_spellCheck}")
print(f"\nsuggestions: {doc._.suggestions_spellCheck}")
print(f"\nspell check output (str): {doc._.outcome_spellCheck}")
print(f"\nspell check score: {doc._.score_spellCheck}")
print("\nTokens from spacy doc:")
for token in doc:
    print(f"    {token.text}")
# Out:
# nlp.pipe_names before adding contextualSpellCheck: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
#
# nlp.pipe_names after  adding contextualSpellCheck: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner', 'contextual spellchecker']
#
# contextualSpellCheck added as extension: True
#
# spell check performed: True
#
# suggestions: {milion: 'million', milion: 'million'}
#
# spell check output (str): Income was $9.4 million compared to the prior year of $2.7 million
#
# spell check score: {milion: [('million', 0.42275), (',', 0.23874), ('mi', 0.13952), ('billion', 0.10526), ('trillion', 0.01076), ('%', 0.00577), ('Mi', 0.00542), ('##M', 0.00512), ('.', 0.00276), ('Million', 0.00268)], milion: [('.', 0.99228), (';', 0.00648), ('!', 0.00054), ('million', 0.0003), ('billion', 0.00014), ('?', 5e-05), ('...', 2e-05), ('|', 2e-05), ('%', 1e-05), (',', 1e-05)]}
#
# Tokens from spacy doc:
#     Income
#     was
#     $
#     9.4
#     milion
#     compared
#     to
#     the
#     prior
#     year
#     of
#     $
#     2.7
#     milion

# %% [markdown]
# ### Add contextualSpellCheck to spaCy pipeline manually

# %%
import spacy
import contextualSpellCheck

nlp = spacy.load("en_core_web_sm")
print(f"nlp.pipe_names before adding contextualSpellCheck: {nlp.pipe_names}")
nlp.add_pipe("contextual spellchecker")
print(f"\nnlp.pipe_names after adding contextualSpellCheck: {nlp.pipe_names}")
doc = nlp("Income was $9.4 milion compared to the prior year of $2.7 milion")
print(f"\ncontextualSpellCheck added as extension: {doc._.contextual_spellCheck}")
print(f"\nspell check performed: {doc._.performed_spellCheck}")
print(f"\nsuggestions: {doc._.suggestions_spellCheck}")
print(f"\nspell check output (str): {doc._.outcome_spellCheck}")
print(f"\nspell check score: {doc._.score_spellCheck}")
print("\nTokens from spacy doc:")
for token in doc:
    print(f"    {token.text}")
# Out:
# nlp.pipe_names before adding contextualSpellCheck: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
#
# nlp.pipe_names after adding contextualSpellCheck: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner', 'contextual spellchecker']
#
# contextualSpellCheck added as extension: True
#
# spell check performed: True
#
# suggestions: {milion: 'million', milion: 'million'}
#
# spell check output (str): Income was $9.4 million compared to the prior year of $2.7 million
#
# spell check score: {milion: [('million', 0.42275), (',', 0.23874), ('mi', 0.13952), ('billion', 0.10526), ('trillion', 0.01076), ('%', 0.00577), ('Mi', 0.00542), ('##M', 0.00512), ('.', 0.00276), ('Million', 0.00268)], milion: [('.', 0.99228), (';', 0.00648), ('!', 0.00054), ('million', 0.0003), ('billion', 0.00014), ('?', 5e-05), ('...', 2e-05), ('|', 2e-05), ('%', 1e-05), (',', 1e-05)]}
#
# Tokens from spacy doc:
#     Income
#     was
#     $
#     9.4
#     milion
#     compared
#     to
#     the
#     prior
#     year
#     of
#     $
#     2.7
#     milion

# %% [markdown]
# ## autocorrect
# This package takes in raw text and returns a string. The documentation is almost nonexistant but it is straightforward to use.
#
# See also:
#
# https://github.com/filyp/autocorrect

# %%
import autocorrect
spell = autocorrect.Speller()
text = "I'm not sleapy and tehre is no place I'm giong to."
corrected_text = spell(text)
print(type(corrected_text))
print(corrected_text)
# Out:
# <class 'str'>
# I'm not sleepy and there is no place I'm going to.

# %%
spell.nlp_data
# Out:
# {'the': 233895398,
#  'quot': 213246452,
#  'gt': 205418321,
#  'lt': 201905902,
#  'of': 170579870,
#  'and': 114915476,
#  'in': 108775489,
#  'ref': 100113710,
#  'to': 98730471,
#  'a': 85162020,
#  'title': 73550351,
#  'id': 69106380,
#  'amp': 59580286,
#  'text': 49932705,
#  'name': 44535519,
#  'for': 44441763,
#  'www': 43570174,
#  'is': 42198707,
#  'page': 39923675,
#  'date': 38495767,
#  'on': 37846907,
#  'was': 36132835,
#  'url': 35692533,
#  'by': 32609005,
#  'as': 32487902,
#  'web': 31676606,
#  'talk': 30204069,
#  'with': 28779790,
#  'style': 27614637,
#  'from': 26214177,
#  'that': 26111833,
#  'http': 25949611,
#  'align': 25283213,
#  'x': 23696536,
#  'T': 23160548,
#  'at': 23015718,
#  'wiki': 22578550,
#  'format': 22332741,
#  'space': 22275634,
#  'The': 20940732,
#  'Z': 20835536,
#  'username': 20821718,
#  'model': 20805820,
#  'timestamp': 20698965,
#  'first': 20651434,
#  'revision': 20503997,
#  'ns': 20427646,
#  'bytes': 20334761,
#  'contributor': 20297538,
#  'sha': 20219154,
#  'wikitext': 20214430,
#  'comment': 20201237,
#  'it': 19069339,
#  'https': 18166905,
#  'small': 18155611,
#  'be': 17767313,
#  'X': 17526540,
#  'an': 17280280,
#  'accessdate': 16989484,
#  'link': 16620497,
#  'center': 16339842,
#  'br': 16219891,
#  'not': 15487037,
#  'last': 15478955,
#  'this': 15451264,
#  'span': 15429492,
#  'publisher': 14821691,
#  'COIBot': 14759367,
#  's': 14546345,
#  'U': 14284872,
#  'en': 14204632,
#  'parentid': 14095682,
#  'I': 13898167,
#  'L': 13839748,
#  'color': 13638808,
#  'are': 13507484,
#  'or': 13333693,
#  'his': 13280953,
#  'font': 12837923,
#  'A': 12611516,
#  'news': 12543076,
#  'domain': 12165111,
#  'article': 11341453,
#  'background': 11253470,
#  'he': 11077035,
#  'w': 11057746,
#  'UL': 10752931,
#  'WUL': 10740087,
#  'team': 10611388,
#  'px': 10564165,
#  'has': 10251209,
#  'OtherLinks': 10240432,
#  'left': 9981304,
#  'year': 9753850,
#  'which': 9732367,
#  'nbsp': 9636509,
#  'F': 9475386,
#  'RD': 9391391,
#  'image': 9215246,
#  'were': 9169238,
#  'also': 9067524,
#  'work': 9062346,
#  'have': 8969574,
#  'REDIRECT': 8913829,
#  'index': 8775289,
#  'D': 8641347,
#  'base': 8583161,
#  'but': 8492532,
#  'New': 8312685,
#  'de': 8228041,
#  'basedomain': 8122278,
#  'baseip': 8122278,
#  'website': 8112781,
#  'you': 8069503,
#  'th': 8013343,
#  'p': 7909801,
#  'class': 7882013,
#  'C': 7858657,
#  'type': 7769623,
#  'time': 7766698,
#  'deletion': 7765722,
#  'discussion': 7763359,
#  'March': 7720310,
#  'May': 7709888,
#  'one': 7644515,
#  'archive': 7612472,
#  'January': 7533030,
#  'States': 7314721,
#  'April': 7310264,
#  'diff': 7284450,
#  'score': 7281594,
#  'October': 7237939,
#  'other': 7211540,
#  'July': 7123823,
#  'B': 7111830,
#  'no': 7084072,
#  'September': 7074889,
#  'United': 7052003,
#  'sup': 7048863,
#  'August': 6974718,
#  'December': 6897218,
#  'June': 6887954,
#  'd': 6882651,
#  'November': 6848204,
#  'n': 6690819,
#  'had': 6670749,
#  'February': 6592701,
#  'm': 6459657,
#  'been': 6451475,
#  'who': 6446851,
#  'language': 6397771,
#  'right': 6358652,
#  'all': 6357847,
#  'American': 6350246,
#  'their': 6347098,
#  'E': 6320640,
#  'e': 6212944,
#  'County': 6086680,
#  'made': 6073485,
#  'new': 6070583,
#  'b': 6052187,
#  'width': 5958477,
#  'oldid': 5930752,
#  'top': 5873104,
#  'its': 5811327,
#  'football': 5769790,
#  'about': 5768472,
#  'status': 5729992,
#  'Category': 5693633,
#  'f': 5591091,
#  'should': 5504776,
#  'author': 5492287,
#  'people': 5475540,
#  'more': 5466258,
#  'access': 5445153,
#  'there': 5437024,
#  'links': 5420320,
#  'References': 5418491,
#  'they': 5330267,
#  'list': 5305681,
#  'book': 5303642,
#  'her': 5267455,
#  'pages': 5261978,
#  'two': 5219110,
#  'years': 5173953,
#  'can': 5136845,
#  'World': 5134864,
#  'would': 5087714,
#  'do': 5083411,
#  'season': 5069974,
#  'up': 5029348,
#  'Wikipedia': 5025331,
#  'after': 5011295,
#  'articles': 5007038,
#  'University': 5004855,
#  'journal': 4996241,
#  'redirect': 4956765,
#  'c': 4918574,
#  'User': 4763068,
#  'film': 4637904,
#  'box': 4591745,
#  'area': 4579131,
#  'York': 4528717,
#  'books': 4501760,
#  'location': 4467188,
#  'rowspan': 4462357,
#  'review': 4450453,
#  'only': 4385505,
#  'bgcolor': 4262997,
#  'Articles': 4257068,
#  'into': 4256987,
#  'i': 4202199,
#  'place': 4189233,
#  'S': 4180821,
#  'y': 4158151,
#  'State': 4108452,
#  'if': 4070176,
#  'M': 4036537,
#  'dead': 4021625,
#  'v': 4015573,
#  'size': 3978379,
#  'use': 3959111,
#  'category': 3942970,
#  'League': 3889975,
#  'out': 3883597,
#  'population': 3860631,
#  'series': 3859492,
#  't': 3852964,
#  'R': 3841445,
#  'end': 3840414,
#  'album': 3834987,
#  'J': 3820269,
#  'user': 3819603,
#  'edit': 3818151,
#  'party': 3806508,
#  'when': 3792261,
#  'Party': 3776832,
#  'nowiki': 3772882,
#  'em': 3757205,
#  'National': 3751661,
#  'km': 3715387,
#  'caption': 3690028,
#  'some': 3685831,
#  'using': 3675064,
#  'l': 3675022,
#  'over': 3674748,
#  'subdivision': 3665974,
#  'South': 3664940,
#  'City': 3663165,
#  'so': 3613927,
#  'will': 3588733,
#  'r': 3567263,
#  'than': 3564872,
#  'used': 3547663,
#  'School': 3537716,
#  'history': 3489570,
#  'colspan': 3480809,
#  'yes': 3470237,
#  'Template': 3452517,
#  'border': 3407260,
#  'N': 3394234,
#  'Q': 3387126,
#  'div': 3363278,
#  'map': 3307495,
#  'o': 3305605,
#  'she': 3273742,
#  'John': 3261037,
#  'In': 3258010,
#  'result': 3234881,
#  'English': 3222300,
#  'then': 3206564,
#  'player': 3190713,
#  'free': 3183711,
#  'Contributions': 3182462,
#  'k': 3180822,
#  'birth': 3177762,
#  'goals': 3141314,
#  'state': 3121893,
#  'where': 3098100,
#  'issue': 3085824,
#  'q': 3068152,
#  'any': 3035649,
#  'P': 3025236,
#  'History': 3021056,
#  'External': 3004480,
#  'stub': 2992612,
#  'being': 2987787,
#  'music': 2978109,
#  'most': 2952645,
#  'deleted': 2948072,
#  'white': 2941497,
#  'family': 2939496,
#  'such': 2937030,
#  'him': 2931696,
#  'group': 2927137,
#  'age': 2924469,
#  'ndash': 2921392,
#  'Cup': 2917616,
#  'District': 2914491,
#  'number': 2882000,
#  'them': 2881852,
#  'W': 2876209,
#  'election': 2871332,
#  'match': 2866203,
#  'War': 2856247,
#  'under': 2844528,
#  'between': 2840900,
#  'country': 2820217,
#  'added': 2818451,
#  'during': 2816951,
#  'thumb': 2812667,
#  'players': 2798630,
#  'H': 2796954,
#  'before': 2778124,
#  'red': 2774371,
#  'action': 2772710,
#  'century': 2765932,
#  'British': 2763334,
#  'North': 2755478,
#  'volume': 2746443,
#  'closed': 2742458,
#  'three': 2733640,
#  'like': 2719576,
#  'city': 2718355,
#  'game': 2712258,
#  'G': 2711838,
#  'death': 2689113,
#  'part': 2686031,
#  'US': 2683819,
#  'your': 2680785,
#  'AWB': 2670811,
#  'File': 2669330,
#  'isbn': 2664554,
#  'WikiProject': 2644725,
#  'code': 2624938,
#  'well': 2620768,
#  'h': 2619608,
#  'known': 2616778,
#  'archivedate': 2611147,
#  'archiveurl': 2601768,
#  'u': 2601048,
#  'g': 2591573,
#  'may': 2586106,
#  'scope': 2574746,
#  'AES': 2571585,
#  'what': 2571338,
#  'lang': 2559566,
#  'sub': 2559282,
#  'line': 2557634,
#  'change': 2517117,
#  'section': 2517040,
#  'comments': 2502107,
#  'display': 2496607,
#  'sources': 2450553,
#  'df': 2424886,
#  'against': 2416191,
#  'row': 2415580,
#  'many': 2411003,
#  'edits': 2401157,
#  'II': 2386897,
#  'school': 2384519,
#  'Summer': 2378944,
#  'we': 2375143,
#  'following': 2369815,
#  'candidate': 2367420,
#  'Redirected': 2365334,
#  'established': 2355814,
#  'St': 2351138,
#  'through': 2350236,
#  'length': 2348524,
#  'International': 2340894,
#  'wikitable': 2329385,
#  'site': 2325788,
#  'content': 2315789,
#  'see': 2311023,
#  'st': 2310616,
#  'j': 2310463,
#  'later': 2306509,
#  'just': 2290398,
#  'start': 2287974,
#  'now': 2286148,
#  'control': 2283311,
#  'live': 2283251,
#  'same': 2278422,
#  'my': 2264369,
#  'per': 2263891,
#  'debate': 2262268,
#  'House': 2259406,
#  'Press': 2255406,
#  'further': 2252497,
#  'song': 2250940,
#  'station': 2247196,
#  'source': 2244439,
#  'College': 2237125,
#  'moved': 2234439,
#  'label': 2231802,
#  'here': 2219701,
#  'world': 2213112,
#  'second': 2204112,
#  'This': 2200880,
#  'Deletion': 2194952,
#  'No': 2192695,
#  'above': 2190079,
#  'based': 2178386,
#  'both': 2172678,
#  'It': 2171807,
#  'report': 2166108,
#  'national': 2162655,
#  'these': 2158031,
#  'News': 2140477,
#  'solid': 2139235,
#  'West': 2136586,
#  'total': 2135619,
#  'could': 2116815,
#  'Park': 2116265,
#  'me': 2107631,
#  'doi': 2107449,
#  'released': 2098137,
#  'contribs': 2097886,
#  'noinclude': 2092585,
#  'because': 2087032,
#  'data': 2079886,
#  'Bot': 2072385,
#  'editor': 2068972,
#  'while': 2068247,
#  'including': 2064507,
#  'nomination': 2061523,
#  'nd': 2060503,
#  'story': 2060109,
#  'Women': 2059873,
#  'region': 2059692,
#  'description': 2053684,
#  'bot': 2047973,
#  'delete': 2041787,
#  'Times': 2038840,
#  'information': 2038347,
#  'K': 2034972,
#  'Australia': 2030046,
#  'weight': 2026685,
#  'high': 2022128,
#  'See': 2020706,
#  'Games': 2015317,
#  'India': 2007306,
#  'London': 2003151,
#  'People': 2000897,
#  'record': 2000148,
#  'show': 1996960,
#  'became': 1995981,
#  'Football': 1988597,
#  'life': 1985790,
#  'USA': 1985577,
#  'search': 1981773,
#  'dmy': 1972965,
#  'England': 1968417,
#  'since': 1967369,
#  'home': 1954179,
#  'double': 1950431,
#  'single': 1932152,
#  'below': 1918941,
#  'position': 1908547,
#  'seed': 1900839,
#  'men': 1899885,
#  'z': 1893990,
#  'day': 1892105,
#  'French': 1890631,
#  'Championships': 1886011,
#  'California': 1879061,
#  'newspaper': 1875100,
#  'long': 1868033,
#  'O': 1860978,
#  'until': 1859646,
#  'Year': 1859350,
#  'European': 1858924,
#  'Division': 1857172,
#  'Special': 1848547,
#  'back': 1837573,
#  'Championship': 1836186,
#  'Log': 1826698,
#  'footnotes': 1819412,
#  'TV': 1818340,
#  'appropriate': 1813555,
#  'found': 1811682,
#  'Association': 1802605,
#  'Music': 1800701,
#  'German': 1795825,
#  'government': 1792763,
#  'FF': 1789826,
#  'next': 1789356,
#  'very': 1787432,
#  'women': 1785092,
#  'won': 1783671,
#  'main': 1782964,
#  'non': 1779376,
#  'America': 1773716,
#  'system': 1767121,
#  'High': 1766965,
#  'cover': 1765376,
#  'former': 1761335,
#  'votes': 1760976,
#  'Talk': 1759289,
#  'undo': 1758835,
#  'make': 1758430,
#  'old': 1748893,
#  'leader': 1748509,
#  'club': 1746823,
#  'Ship': 1743265,
#  'la': 1740931,
#  'math': 1737181,
#  'abbr': 1733197,
#  'films': 1727643,
#  'without': 1722797,
#  'off': 1722702,
#  'company': 1722383,
#  'term': 1720223,
#  'local': 1717371,
#  'List': 1716613,
#  'Kingdom': 1715314,
#  'Time': 1713707,
#  'David': 1713041,
#  'Award': 1711055,
#  'create': 1711042,
#  'born': 1709763,
#  'district': 1704812,
#  'artist': 1702658,
#  'alt': 1701528,
#  'Church': 1696382,
#  'round': 1693789,
#  'played': 1687563,
#  'four': 1683460,
#  'V': 1679655,
#  'did': 1678403,
#  'related': 1671609,
#  'padding': 1670433,
#  'Men': 1670103,
#  'way': 1668581,
#  'Link': 1667366,
#  'Club': 1665512,
#  'modify': 1662869,
#  'how': 1658618,
#  'move': 1657399,
#  'called': 1655841,
#  'included': 1652137,
#  'All': 1649976,
#  'general': 1648174,
#  'River': 1647219,
#  'dates': 1641383,
#  'media': 1636032,
#  'whitelisted': 1634004,
#  'several': 1630494,
#  'project': 1628175,
#  'don': 1627952,
#  'You': 1626300,
#  'does': 1625684,
#  'Canada': 1625666,
#  're': 1609476,
#  'France': 1603331,
#  'named': 1596270,
#  'shading': 1592894,
#  'General': 1592202,
#  'Olympics': 1591171,
#  'members': 1588928,
#  'species': 1580869,
#  'He': 1573789,
#  'bottom': 1573406,
#  'games': 1566119,
#  'Australian': 1560552,
#  'percentage': 1557829,
#  'Best': 1555005,
#  'James': 1552998,
#  'isIP': 1552468,
#  'think': 1550704,
#  'Group': 1548641,
#  'television': 1546203,
#  'col': 1542149,
#  'set': 1541610,
#  'Fixing': 1538985,
#  'pos': 1537738,
#  'births': 1537122,
#  'case': 1536363,
#  'each': 1533007,
#  'version': 1530853,
#  'stadium': 1529429,
#  'still': 1527286,
#  'First': 1527242,
#  'East': 1525979,
#  'pg': 1520525,
#  'Subsequent': 1520105,
#  'mi': 1518062,
#  'career': 1515046,
#  'those': 1511909,
#  'even': 1507067,
#  'early': 1502072,
#  'nowrap': 1501294,
#  'original': 1501285,
#  'Democratic': 1499329,
#  'order': 1495358,
#  'view': 1492943,
#  'video': 1473717,
#  'Awards': 1471110,
#  'own': 1470942,
#  'Company': 1467553,
#  'William': 1463501,
#  'member': 1459445,
#  'bold': 1457981,
#  'much': 1457098,
#  'rationale': 1453782,
#  'note': 1452156,
#  'public': 1451198,
#  'best': 1445120,
#  'short': 1440101,
#  'details': 1438387,
#  'Street': 1437562,
#  'Team': 1434211,
#  'PA': 1430100,
#  'clubs': 1426053,
#  'another': 1421394,
#  'Class': 1420806,
#  'sports': 1420406,
#  'caps': 1417681,
#  'writer': 1410659,
#  'Council': 1410513,
#  'created': 1404994,
#  'good': 1403845,
#  'published': 1402767,
#  'notable': 1399435,
#  'pp': 1396024,
#  'basketball': 1390810,
#  'black': 1390461,
#  'Center': 1389697,
#  'needed': 1386948,
#  'around': 1385001,
#  'win': 1384203,
#  'pagename': 1383780,
#  'margin': 1380585,
#  'sort': 1376150,
#  'know': 1371690,
#  'coordinates': 1367024,
#  'said': 1365177,
#  'results': 1362620,
#  'Film': 1354853,
#  'Records': 1353344,
#  'point': 1353070,
#  'pushpin': 1350969,
#  'band': 1349887,
#  'final': 1344266,
#  'get': 1344248,
#  'special': 1343850,
#  'add': 1341502,
#  'Union': 1340430,
#  'reason': 1337829,
#  'Road': 1336206,
#  'template': 1328730,
#  'logo': 1328562,
#  'Indian': 1327655,
#  'blank': 1325040,
#  'held': 1324823,
#  'sport': 1313774,
#  'Society': 1313158,
#  'Texas': 1311722,
#  'Report': 1309436,
#  'San': 1308724,
#  'built': 1307461,
#  'Washington': 1303145,
#  'service': 1302692,
#  'building': 1299223,
#  'different': 1296872,
#  'Other': 1293845,
#  'UK': 1291463,
#  'person': 1290906,
#  'us': 1289798,
#  'within': 1288041,
#  'Republic': 1287057,
#  'inline': 1286291,
#  'elevation': 1282921,
#  'Journal': 1282737,
#  'down': 1282341,
#  'town': 1281737,
#  'Army': 1280454,
#  'water': 1280076,
#  'ft': 1276415,
#  'China': 1276055,
#  'King': 1273196,
#  'official': 1272671,
#  'must': 1272168,
#  'events': 1271860,
#  'present': 1267870,
#  'support': 1263975,
#  'Zealand': 1259027,
#  'include': 1258567,
#  'Japan': 1258148,
#  'children': 1256523,
#  'help': 1256514,
#  'On': 1251573,
#  'Germany': 1248798,
#  'George': 1247492,
#  'One': 1243595,
#  'Summary': 1239654,
#  'major': 1233439,
#  'via': 1233398,
#  'Stadium': 1233070,
#  'settlement': 1229433,
#  'Republican': 1228577,
#  'release': 1226974,
#  'Island': 1224438,
#  'league': 1222375,
#  'located': 1221499,
#  'Hall': 1214817,
#  'Michael': 1211687,
#  'AfD': 1210957,
#  'began': 1210536,
#  'Central': 1208394,
#  'law': 1208254,
#  'event': 1207259,
#  'Air': 1206816,
#  'community': 1203199,
#  'go': 1200508,
#  'due': 1199804,
#  'please': 1196467,
#  'rd': 1195451,
#  'Robert': 1194379,
#  'days': 1194111,
#  'reference': 1193074,
#  'full': 1191312,
#  'Ireland': 1191246,
#  'Country': 1190037,
#  'again': 1189592,
#  'Africa': 1184000,
#  'large': 1183281,
#  'art': 1182530,
#  'took': 1181738,
#  'info': 1178318,
#  'namespace': 1175717,
#  'value': 1169650,
#  'resolved': 1168839,
#  'replaced': 1164024,
#  'checked': 1163894,
#  'Paul': 1163572,
#  'third': 1161210,
#  'written': 1160647,
#  'take': 1158253,
#  'subject': 1157771,
#  'Japanese': 1156021,
#  'Department': 1155683,
#  'contributions': 1155547,
#  'Military': 1152523,
#  'need': 1150802,
#  'play': 1150137,
#  'tools': 1149141,
#  'al': 1146866,
#  'level': 1146472,
#  'Grand': 1146390,
#  'es': 1144239,
#  'changed': 1141398,
#  'Canadian': 1141378,
#  'shell': 1140330,
#  'Smith': 1140055,
#  'five': 1138877,
#  'Museum': 1138051,
#  'current': 1135633,
#  'others': 1134583,
#  'served': 1129987,
#  'FC': 1129513,
#  'big': 1129265,
#  'find': 1128937,
#  'near': 1126974,
#  'received': 1126752,
#  'Carolina': 1126242,
#  'Article': 1124678,
#  'Thomas': 1124206,
#  'form': 1122635,
#  'Sports': 1122301,
#  'given': 1121652,
#  'points': 1121282,
#  'fr': 1119951,
#  'million': 1118192,
#  'war': 1117951,
#  'height': 1112320,
#  'removed': 1108840,
#  'Red': 1106207,
#  'Living': 1106101,
#  'green': 1104499,
#  'Virginia': 1101584,
#  'along': 1100840,
#  'Man': 1099591,
#  'side': 1098382,
#  'ID': 1094637,
#  'Asian': 1094163,
#  'Province': 1088765,
#  'am': 1086347,
#  'few': 1085191,
#  'pmid': 1081363,
#  'Science': 1080427,
#  'Series': 1080373,
#  'field': 1079660,
#  'away': 1077993,
#  'revid': 1077749,
#  'EditSummary': 1076960,
#  'wikidomain': 1076949,
#  'sortdomain': 1076949,
#  'origdiff': 1076949,
#  'coiflag': 1076949,
#  'research': 1076890,
#  'usercount': 1076719,
#  'blacklisteduser': 1076669,
#  'whitereason': 1076669,
#  'blackreason': 1076669,
#  'Town': 1074846,
#  'Europe': 1074551,
#  'light': 1074142,
#  'Open': 1070277,
#  'attendance': 1069453,
#  'provide': 1068287,
#  'house': 1061899,
#  'Black': 1061560,
#  'Institute': 1059877,
#  'director': 1056863,
#  'otherlinks': 1056730,
#  'listed': 1055281,
#  'edition': 1054556,
#  'village': 1052198,
#  'teams': 1051904,
#  'business': 1048453,
#  'Wales': 1045867,
#  'magazine': 1045245,
#  'power': 1044764,
#  'entry': 1042044,
#  'died': 1038757,
#  'proposed': 1034957,
#  'example': 1033923,
#  'awards': 1030830,
#  'military': 1028693,
#  'described': 1028077,
#  'albums': 1027551,
#  'Reference': 1026255,
#  'prev': 1025963,
#  'native': 1024846,
#  'Life': 1024590,
#  'If': 1023943,
#  'works': 1022770,
#  'includeonly': 1021589,
#  'Art': 1019770,
#  'President': 1019561,
#  'keep': 1019491,
#  'times': 1019253,
#  'Historic': 1018067,
#  'having': 1016918,
#  'land': 1016066,
#  'road': 1015655,
#  'Post': 1014708,
#  'Pennsylvania': 1011974,
#  'ship': 1011349,
#  'Western': 1011036,
#  'table': 1010254,
#  'political': 1007110,
#  'images': 1004560,
#  'role': 1002726,
#  'international': 998593,
#  'templates': 996571,
#  'coach': 995799,
#  'Spanish': 994842,
#  'low': 994768,
#  'Spam': 990716,
#  'head': 990531,
#  'Source': 989380,
#  'mm': 988745,
#  'ru': 988232,
#  'south': 987040,
#  'Star': 985087,
#  'office': 984896,
#  'ff': 984302,
#  'Title': 981101,
#  'producer': 980074,
#  'man': 977900,
#  'White': 977892,
#  'often': 977045,
#  'references': 975747,
#  'Royal': 975428,
#  'notice': 975134,
#  'north': 974716,
#  'son': 973720,
#  'Media': 968953,
#  'Academy': 968128,
#  'face': 962978,
#  'Green': 960651,
#  'Parliament': 960115,
#  'Charles': 959213,
#  'post': 958663,
#  'period': 956284,
#  'Description': 955555,
#  'Italian': 953407,
#  'Day': 953268,
#  'nat': 953126,
#  'Licensing': 953062,
#  'Tom': 952703,
#  'La': 952299,
#  'Education': 951053,
#  'African': 947779,
#  'songs': 947728,
#  'education': 947726,
#  'body': 946347,
#  'too': 946050,
#  'Angeles': 946040,
#  'Peter': 945009,
#  'Research': 942381,
#  'For': 941380,
#  'desk': 939815,
#  'loss': 936042,
#  'Archives': 935604,
#  'Brown': 935242,
#  'topic': 933845,
#  'hockey': 930533,
#  'Railway': 929446,
#  'referee': 927295,
#  'Court': 926774,
#  'run': 926498,
#  'Census': 926361,
#  'Unknown': 924697,
#  'Florida': 923876,
#  'Catholic': 921165,
#  'View': 921023,
#  'production': 917628,
#  'services': 917340,
#  'Love': 916740,
#  'every': 916703,
#  'Image': 916152,
#  'Jersey': 912857,
#  'deaths': 911729,
#  'Service': 911183,
#  'railway': 910626,
#  'density': 908682,
#  'elections': 908235,
#  'names': 907487,
#  'Russian': 906775,
#  'EpisodeNumber': 906453,
#  'Great': 905195,
#  'Conference': 904899,
#  'Russia': 904032,
#  'preserved': 902645,
#  'flag': 902492,
#  'father': 901763,
#  'open': 901156,
#  'III': 901134,
#  'et': 899064,
#  'archived': 898956,
#  'making': 898115,
#  'To': 894648,
#  'characters': 894023,
#  'gold': 892166,
#  'blue': 891452,
#  'started': 889484,
#  'male': 888080,
#  'politician': 886716,
#  'issues': 886095,
#  'Top': 885993,
#  'students': 885118,
#  'become': 884399,
#  'development': 882607,
#  'never': 881981,
#  'di': 881082,
#  'places': 879864,
#  'groups': 877129,
#  'authority': 877085,
#  'recorded': 876578,
#  'auto': 876309,
#  'Hill': 876303,
#  'Saint': 873173,
#  'Review': 872258,
#  'My': 872097,
#  'importance': 870860,
#  'Richard': 870266,
#  'none': 870129,
#  'produced': 870100,
#  'li': 870026,
#  'enough': 869452,
#  'undoafter': 868865,
#  'Airport': 867698,
#  'target': 866506,
#  'episode': 866224,
#  'lead': 866163,
#  'put': 864650,
#  'though': 863479,
#  'Public': 861536,
#  'function': 860252,
#  'led': 860196,
#  'categories': 860086,
#  'Georgia': 858929,
#  'da': 857857,
#  'already': 857319,
#  'church': 855577,
#  'Lake': 854994,
#  'Please': 852202,
#  'Chinese': 851733,
#  'question': 851423,
#  'want': 851279,
#  'late': 851070,
#  'consensus': 849970,
#  'Force': 849427,
#  'com': 849027,
#  'Empire': 848674,
#  'WP': 847707,
#  ...}

# %%
min(spell.nlp_data, key=spell.nlp_data.get)
# Out:
# 'inefficiency'

# %%
spell.nlp_data['inefficiency']
# Out:
# 2401

# %% [markdown]
# ### Can add to the autocorrect dictionary

# %%
spell.nlp_data.update({'Zumba': 1000}) # what does the number represent?

# %%
spell.nlp_data['Zumba']
# Out:
# 1000

# %%
spell.nlp_data['accompanying']
# Out:
# 56121

# %% [markdown]
# ## textblob
# This package can perform a number of NLP tasks including:
# - POS tagging
# - Noun phrase extraction
# - Sentiment analysis
# - Tokenization
# - Word inflection and lemmatization
# - WordNet integration
# - WordLists
# - Spelling correction
# - Word and noun phrase frequencies
# - Parsing
# - n-grams
# - Start and end indices of sentences
#
# The initial text string is converted into a textblob object and would need to be converted back to a string to pass into spaCy.
#
# See also:
#
# https://github.com/sloria/textblob

# %%
from textblob import TextBlob
from textblob import Sentence
import textblob as tb
tb.en.spelling.update({'Zumba': 1}) # same as autocorrect, what does the number represent?
text = "A sentencee to checkk! Zumba!"
# using a TextBlob
blob = TextBlob(text)
result = blob.correct()
print(type(result))
print(result)
print(str(result))
# cast to string for use in spaCy
result2 = str(result)
# using a Sentence
sentence = Sentence(text)
print(str(sentence.correct()))
# Out:
# <class 'textblob.blob.TextBlob'>
# A sentence to check! Zumba!
# A sentence to check! Zumba!
# A sentence to check! Zumba!

# %%
tb.en.spelling['accompanying']
# Out:
# 18
