# %%
import os, sys
nlpPath = os.path.join(os.getcwd(), '..', '..', '..')
sys.path.append(nlpPath)

# %%
import pandas as pd

# %%
csvPath = os.path.join(os.getcwd(), 'excavator_2015_raw_forpdl.csv')

# %%
excavator_df = pd.read_csv(csvPath)

# %%
excavator_df.head()
# Out:
#   BscStartDate Asset        OriginalShorttext PMType     Cost
# 0   2004-07-01     A        BUCKET WON'T OPEN   PM01   183.05
# 1   2005-03-20     A  L/H BUCKET CYL LEAKING.   PM01   407.40
# 2   2006-05-05     A              SWAP BUCKET   PM01     0.00
# 3   2006-07-11     A         FIT BUCKET TOOTH   PM01     0.00
# 4   2006-11-10     A       REFIT BUCKET TOOTH   PM01  1157.27

# %%
len(excavator_df)
# Out:
# 5485

# %%
excavator_df['OriginalShorttext'][191:200]
# Out:
# 191          Change out bucket teeth.
# 192     REPLACE MISSING BUCKET TOOTH.
# 193    REPLACE A MISSING BUCKET TOOTH
# 194              REPLACE BUCKET TOOTH
# 195      BUCKET TOOTH MISSING    @R10
# 196     REPLACE MISSING BUCKET TOOTH.
# 197         REPAIR BUCKET WEAR PLATES
# 198                     BUCKET CRACKS
# 199              REPLACE BUCKET TOOTH
# Name: OriginalShorttext, dtype: object

# %%
# looked at OriginalShorttext from 0:200 for these entities
entity_list = ['Adapter', 
               'Adapter pin',
               'Adaptor', 
               'Adaptors', 
               'Adaptor keeper pin',
               'Adaptor pins', 
               'Air con.', 
               'Boom',
               'Bucket', 
               'Bucket clam', 
               'Bucket clam cylinder',
               'Bucket clam pipe', 
               'Bucket crowd cylinder',
               'Bucket cyl',
               'Bucket cylinder',
               'Bucket cylinder grease line', 
               'Bucket grease line', 
               'Bucket hose', 
               'Bucket lube fittings', 
               'Bucket pin', 
               'Bucket ram hyd hose',
               'Bucket roll cylinder',
               'Bucket teeth', 
               'Bucket tip', 
               'Bucket tips',
               'Bucket tooth', 
               'Bucket wear plates',
               'Gland seal', 
               'Grease fitting',
               'Grease hose bucket pin',
               'Grease line', 
               'Grease lines', 
               'Hose', 
               'Hydraulic oil hose',
               'Lip', 
               'Lip ear',
               'Lip shroud',
               'Lip shrouds', 
               'Lip shroud pin'
               'Lip tips', 
               'Lower wear edge plate', 
               'Lube fitting', 
               'Lube hose',
               'Lube line',
               'Pin',
               'Pins',
               'Stick',
               'Teeth',
               'Tip', 
               'Tooth', 
               'Wear package', 
               'Wear plates']

# %%
entity_df = pd.DataFrame({'Entities': entity_list})

# %%
entity_df
# Out:
#                        Entities
# 0                       Adapter
# 1                   Adapter pin
# 2                       Adaptor
# 3                      Adaptors
# 4            Adaptor keeper pin
# 5                  Adaptor pins
# 6                      Air con.
# 7                          Boom
# 8                        Bucket
# 9                   Bucket clam
# 10         Bucket clam cylinder
# 11             Bucket clam pipe
# 12        Bucket crowd cylinder
# 13                   Bucket cyl
# 14              Bucket cylinder
# 15  Bucket cylinder grease line
# 16           Bucket grease line
# 17                  Bucket hose
# 18         Bucket lube fittings
# 19                   Bucket pin
# 20          Bucket ram hyd hose
# 21         Bucket roll cylinder
# 22                 Bucket teeth
# 23                   Bucket tip
# 24                  Bucket tips
# 25                 Bucket tooth
# 26           Bucket wear plates
# 27                   Gland seal
# 28               Grease fitting
# 29       Grease hose bucket pin
# 30                  Grease line
# 31                 Grease lines
# 32                         Hose
# 33           Hydraulic oil hose
# 34                          Lip
# 35                      Lip ear
# 36                   Lip shroud
# 37                  Lip shrouds
# 38       Lip shroud pinLip tips
# 39        Lower wear edge plate
# 40                 Lube fitting
# 41                    Lube hose
# 42                    Lube line
# 43                          Pin
# 44                         Pins
# 45                        Stick
# 46                        Teeth
# 47                          Tip
# 48                        Tooth
# 49                 Wear package
# 50                  Wear plates

# %%
# # write entities to a csv
# entityPath = os.path.join(os.getcwd(), '..', '..', 'data', 'testing_data', 'excavator_entities.csv')
# entity_df = pd.DataFrame({'Entities': entity_list})
# entity_df.to_csv(entityPath, index=False)

# # write text to a file
# txtPath = os.path.join(os.getcwd(), '..', '..', 'data', 'testing_data', 'excavator.txt')
# with open(txtPath, 'w') as f:
#     f.write(".\n".join(excavator_df['OriginalShorttext'][0:200]))

# %% [markdown]
# ## Follow Congjian's Process

# %%
from nlp.RuleBasedMatcher import RuleBasedMatcher
from nlp import config
from nlp.nlp_utils import generatePatternList
import spacy
nlp = spacy.load("en_core_web_lg", exclude=[])
import logging
logging.basicConfig(format='%(asctime)s %(name)-20s %(levelname)-8s %(message)s', datefmt='%d-%b-%y %H:%M:%S', level=logging.DEBUG)

# %% [markdown]
# ### Read and process entities

# %%
ents = []
entityFile = config.nlpConfig['files']['entity_file']
entityList = pd.read_csv(entityFile).values.ravel().tolist()
ents.extend(entityList)
ents = set(ents)
label = "excavator_component"
entId = "SSC"
patternsOPM = generatePatternList(ents, label=label, id=entId, nlp=nlp, attr="LEMMA")

# %%
patternsOPM
# Out:
# [{'label': 'excavator_component',
#   'pattern': [{'LOWER': 'adaptor'}, {'LOWER': 'keeper'}, {'LOWER': 'pin'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'adaptor'}, {'LEMMA': 'keeper'}, {'LEMMA': 'pin'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'lube'}, {'LOWER': 'fittings'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'lube'}, {'LEMMA': 'fitting'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'},
#    {'LOWER': 'ram'},
#    {'LOWER': 'hyd'},
#    {'LOWER': 'hose'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'},
#    {'LEMMA': 'ram'},
#    {'LEMMA': 'hyd'},
#    {'LEMMA': 'hose'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'grease'},
#    {'LOWER': 'hose'},
#    {'LOWER': 'bucket'},
#    {'LOWER': 'pin'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'grease'},
#    {'LEMMA': 'hose'},
#    {'LEMMA': 'bucket'},
#    {'LEMMA': 'pin'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LOWER': 'lip'}], 'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LEMMA': 'lip'}], 'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'tips'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'tip'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LOWER': 'tip'}], 'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LEMMA': 'tip'}], 'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LOWER': 'boom'}], 'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LEMMA': 'boom'}], 'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'teeth'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'tooth'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'wear'}, {'LOWER': 'plates'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'wear'}, {'LEMMA': 'plate'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'lube'}, {'LOWER': 'line'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'lube'}, {'LEMMA': 'line'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'hydraulic'}, {'LOWER': 'oil'}, {'LOWER': 'hose'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'hydraulic'}, {'LEMMA': 'oil'}, {'LEMMA': 'hose'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LOWER': 'pins'}], 'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LEMMA': 'pin'}], 'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'wear'}, {'LOWER': 'plates'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'wear'}, {'LEMMA': 'plate'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'clam'}, {'LOWER': 'cylinder'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'clam'}, {'LEMMA': 'cylinder'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'adaptor'}, {'LOWER': 'pins'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'adaptor'}, {'LEMMA': 'pin'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'lip'}, {'LOWER': 'shroud'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'lip'}, {'LEMMA': 'shroud'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LOWER': 'pin'}], 'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LEMMA': 'pin'}], 'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'tooth'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'tooth'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'grease'}, {'LOWER': 'line'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'grease'}, {'LEMMA': 'line'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'adapter'}, {'LOWER': 'pin'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'adapter'}, {'LEMMA': 'pin'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'grease'}, {'LOWER': 'fitting'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'grease'}, {'LEMMA': 'fitting'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'lip'},
#    {'LOWER': 'shroud'},
#    {'LOWER': 'pinlip'},
#    {'LOWER': 'tips'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'lip'},
#    {'LEMMA': 'shroud'},
#    {'LEMMA': 'pinlip'},
#    {'LEMMA': 'tip'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'},
#    {'LOWER': 'cylinder'},
#    {'LOWER': 'grease'},
#    {'LOWER': 'line'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'},
#    {'LEMMA': 'cylinder'},
#    {'LEMMA': 'grease'},
#    {'LEMMA': 'line'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'grease'}, {'LOWER': 'line'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'grease'}, {'LEMMA': 'line'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'roll'}, {'LOWER': 'cylinder'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'roll'}, {'LEMMA': 'cylinder'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'crowd'}, {'LOWER': 'cylinder'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'crowd'}, {'LEMMA': 'cylinder'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'cylinder'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'cylinder'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'air'}, {'LOWER': 'con.'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'air'}, {'LEMMA': 'con'}, {'LEMMA': '.'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'lower'},
#    {'LOWER': 'wear'},
#    {'LOWER': 'edge'},
#    {'LOWER': 'plate'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'low'},
#    {'LEMMA': 'wear'},
#    {'LEMMA': 'edge'},
#    {'LEMMA': 'plate'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'tooth'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'tooth'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'clam'}, {'LOWER': 'pipe'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'clam'}, {'LEMMA': 'pipe'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'lip'}, {'LOWER': 'shrouds'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'lip'}, {'LEMMA': 'shroud'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LOWER': 'hose'}], 'id': 'SSC'},
#  {'label': 'excavator_component', 'pattern': [{'LEMMA': 'hose'}], 'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'gland'}, {'LOWER': 'seal'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'gland'}, {'LEMMA': 'seal'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'lip'}, {'LOWER': 'ear'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'lip'}, {'LEMMA': 'ear'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'tip'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'tip'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'adapter'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'Adapter'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'grease'}, {'LOWER': 'lines'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'grease'}, {'LEMMA': 'line'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'cyl'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'cyl'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'hose'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'hose'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'pin'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'pin'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'teeth'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'tooth'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'wear'}, {'LOWER': 'package'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'wear'}, {'LEMMA': 'package'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'bucket'}, {'LOWER': 'clam'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'bucket'}, {'LEMMA': 'clam'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'lube'}, {'LOWER': 'hose'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'lube'}, {'LEMMA': 'hose'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'stick'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'Stick'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'adaptor'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'adaptor'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'adaptors'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'adaptor'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LOWER': 'lube'}, {'LOWER': 'fitting'}],
#   'id': 'SSC'},
#  {'label': 'excavator_component',
#   'pattern': [{'LEMMA': 'lube'}, {'LEMMA': 'fit'}],
#   'id': 'SSC'}]

# %% [markdown]
# ### Read and process causal key words

# %%
causalLabel = "causal_keywords"
causalID = "causal"
patternsCausal = []
causalFilename = config.nlpConfig['files']['cause_effect_keywords_file']
ds = pd.read_csv(causalFilename, skipinitialspace=True)
for col in ds.columns:
    vars = set(ds[col].dropna())
    patternsCausal.extend(generatePatternList(vars, label=causalLabel, id=causalID, nlp=nlp, attr="LEMMA"))

# %%
patternsCausal
# Out:
# [{'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'stimulate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'stimulate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'bring'}, {'LOWER': 'about'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'bring'}, {'LEMMA': 'about'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'insitute'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'insitute'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'decrease'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'decrease'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'benefit'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'benefit'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'deny'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'deny'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'derive'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'derive'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'induce'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'induce'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'counter'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'counter'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'raise'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'raise'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'expand'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'expand'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'disallow'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'disallow'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'initiate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'initiate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'cause'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'cause'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'improve'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'improve'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'activate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'activate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'augment'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'augment'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'impinge'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'impinge'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'authorize'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'authorize'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'receive'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'receive'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'force'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'Force'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'provoke'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'provoke'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'license'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'license'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'assent'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'assent'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'cause'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'cause'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'initiate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'initiate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'agree'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'agree'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'produce'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'produce'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'compensate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'compensate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'react'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'react'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'spark'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'spark'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'give'}, {'LOWER': 'rise'}, {'LOWER': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'give'}, {'LEMMA': 'rise'}, {'LEMMA': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'render'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'render'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'prohibit'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'prohibit'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'make'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'make'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'subdue'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'subdue'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'advance'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'advance'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'trigger'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'trigger'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'drag'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'drag'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'combat'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'combat'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'repress'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'repress'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'admit'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'admit'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'concede'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'concede'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'foment'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'foment'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'lead'}, {'LOWER': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'lead'}, {'LEMMA': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'perturb'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'perturb'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'propagate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'propagate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'transform'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'transform'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'increase'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'increase'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'achieve'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'achieve'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'effect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'effect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'keep'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'keep'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'lead'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'lead'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'stimulate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'stimulate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'influence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'influence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'reveal'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'reveal'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'modify'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'modify'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'prompt'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'prompt'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'suppress'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'suppress'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'build-up'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'build'}, {'LEMMA': '-'}, {'LEMMA': 'up'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'launch'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'launch'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'constitute'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'constitute'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'drive'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'drive'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'disturb'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'disturb'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'control'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'control'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'decline'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'decline'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'discourage'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'discourage'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'tolerate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'tolerate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'backfire'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'backfire'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'result'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'result'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'decelerate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'decelerate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'enhance'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'enhance'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'ratify'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'ratify'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'derive'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'derive'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'prevent'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'prevent'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'stop'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'stop'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'decrease'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'decrease'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'facilitate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'facilitate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'consent'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'consent'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'turn'}, {'LOWER': 'on'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'turn'}, {'LEMMA': 'on'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'impede'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'impede'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'affect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'affect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'create'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'create'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'promote'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'promote'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'restrain'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'restrain'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'trigger'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'trigger'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'determine'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'determine'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'increase'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'increase'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'refuse'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'refuse'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'preclude'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'preclude'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'originate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'originate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'damage'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'damage'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'precipitate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'precipitate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'stop'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'stop'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'make'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'make'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'induce'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'induce'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'alter'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'alter'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'start'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'start'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'retain'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'retain'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'deactivate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'deactivate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'facilitate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'facilitate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'actuate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'actuate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'simulate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'simulate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'influence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'influence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'create'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'create'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'generate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'generate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'prevent'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'prevent'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'upset'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'Upset'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'switch'}, {'LOWER': 'on'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'switch'}, {'LEMMA': 'on'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'disapprove'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'disapprove'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'develop'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'develop'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'sanction'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'sanction'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'construct'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'construct'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'accelerate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'accelerate'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'force'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'force'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'affect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'affect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'permit'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'permit'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'confirm'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'confirm'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'hold'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'hold'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'begin'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'begin'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'change'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'change'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'encourage'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'encourage'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'harm'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'harm'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'expedite'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'expedite'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'contribute'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'contribute'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'set'}, {'LOWER': 'up'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'set'}, {'LEMMA': 'up'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'reject'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'reject'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'result'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'result'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'compose'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'compose'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'actor'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'actor'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'product'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'product'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'source'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'source'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'benefit'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'benefit'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'creator'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'creator'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'ground'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'ground'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'end'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'end'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'outcome'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'outcome'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'effect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'effect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'factor'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'factor'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'impact'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'impact'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'condition'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'condition'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'reason'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'reason'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'agent'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'agent'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'consequence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'consequence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'author'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'author'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'influence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'influence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'harm'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'harm'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'damage'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'damage'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'issue'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'issue'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'outgrowth'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'outgrowth'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'event'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'event'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'creation'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'creation'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'result'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'result'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'because'}, {'LOWER': 'of'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'because'}, {'LEMMA': 'of'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'so'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'so'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'accordingly'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'accordingly'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'leads'}, {'LOWER': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'lead'}, {'LEMMA': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'for'}, {'LOWER': 'that'}, {'LOWER': 'reason'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'for'}, {'LEMMA': 'that'}, {'LEMMA': 'reason'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'hence'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'hence'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'consequently'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'consequently'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'as'}, {'LOWER': 'a'}, {'LOWER': 'result'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'as'}, {'LEMMA': 'a'}, {'LEMMA': 'result'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'if'}, {'LOWER': 'then'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'if'}, {'LEMMA': 'then'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'therefore'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'therefore'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'thus'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'thus'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'since'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'since'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'due'}, {'LOWER': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'due'}, {'LEMMA': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'on'}, {'LOWER': 'account'}, {'LOWER': 'of'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'on'}, {'LEMMA': 'account'}, {'LEMMA': 'of'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'results'}, {'LOWER': 'in'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'result'}, {'LEMMA': 'in'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'because'}, {'LOWER': 'of'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'because'}, {'LEMMA': 'of'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'as'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'as'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'since'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'since'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'due'}, {'LOWER': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'due'}, {'LEMMA': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'on'}, {'LOWER': 'account'}, {'LOWER': 'of'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'on'}, {'LEMMA': 'account'}, {'LEMMA': 'of'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'because'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'because'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'result'}, {'LOWER': 'in'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'result'}, {'LEMMA': 'in'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'so'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'so'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'accordingly'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'accordingly'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'eventually'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'eventually'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'hence'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'hence'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'consequently'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'consequently'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'lead'}, {'LOWER': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'lead'}, {'LEMMA': 'to'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'therefore'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'therefore'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'thus'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'thus'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'as'}, {'POS': 'DET', 'OP': '?'}, {'LOWER': 'result'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'as'}, {'POS': 'DET', 'OP': '?'}, {'LEMMA': 'result'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'subsequently'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'subsequently'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'finally'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'finally'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'for'},
#    {'POS': 'DET', 'OP': '?'},
#    {'LOWER': 'reason'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'for'},
#    {'POS': 'DET', 'OP': '?'},
#    {'LEMMA': 'reason'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'ultimately'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'ultimately'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'creator'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'creator'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'determination'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'determination'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'improvement'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'improvement'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'development'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'development'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'agent'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'agent'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'actor'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'actor'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'event'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'event'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'source'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'source'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'creation'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'creation'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'compensation'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'compensation'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'ramification'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'ramification'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'author'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'author'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'fallout'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'fallout'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'evolution'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'evolution'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'factor'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'factor'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'reason'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'reason'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'cause'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'cause'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LOWER': 'issue'}], 'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'issue'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'implication'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'implication'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'product'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'product'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'kickback'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'kickback'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'benefit'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'benefit'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'byproduct'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'byproduct'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'recoil'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'recoil'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'rebound'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'rebound'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'outcome'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'outcome'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'aftereffect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'aftereffect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'side'}, {'LOWER': 'effect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'side'}, {'LEMMA': 'effect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'effect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'effect'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'reaction'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'reaction'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'conclusion'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'conclusion'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'counterbalance'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'counterbalance'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'feedback'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'feedback'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'impact'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'impact'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'aftermath'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'aftermath'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'finding'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords', 'pattern': [{'LEMMA': 'find'}], 'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'countermove'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'countermove'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'consequence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'consequence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'explanation'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'explanation'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'influence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'influence'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'backfire'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'backfire'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'countreaction'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'countreaction'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'repercussion'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'repercussion'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'outgrowth'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'outgrowth'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LOWER': 'result'}],
#   'id': 'causal'},
#  {'label': 'causal_keywords',
#   'pattern': [{'LEMMA': 'result'}],
#   'id': 'causal'}]

# %% [markdown]
# ### Create Rule-based matcher with entity list and causal list

# %%
name = 'ssc_entity_ruler'
matcher = RuleBasedMatcher(nlp, entLabel=entId, causalKeywordLabel=causalID)
matcher.addEntityPattern(name, patternsOPM)

causalName = 'causal_keywords_entity_ruler'
matcher.addEntityPattern(causalName, patternsCausal)
# Out:
# 06-Dec-22 14:15:49 nlp.RuleBasedMatcher INFO     Create instance of RuleBasedMatcher
# 06-Dec-22 14:15:52 nlp.nlp_utils        INFO     Model: core_web_lg, Language: en
# 06-Dec-22 14:15:52 nlp.nlp_utils        INFO     Available pipelines:pysbdSentenceBoundaries, tok2vec, tagger, parser, attribute_ruler, lemmatizer, mergePhrase, normEntities, initCoref, aliasResolver, coreferee, anaphorCoref, anaphorEntCoref

# %% [markdown]
# ### Read text file back in

# %%
textFile = config.nlpConfig['files']['text_file']
with open(textFile, 'r') as ft:
    doc = ft.read()

# %% [markdown]
# ### Process data with matcher

# %%
# matcher(doc)

# %% [markdown]
# ## Process line by line

# %%
i = 1
print(excavator_df['OriginalShorttext'][i])
name = 'ssc_entity_ruler'
matcher = RuleBasedMatcher(nlp, entLabel=entId, causalKeywordLabel=causalID)
matcher.addEntityPattern(name, patternsOPM)

causalName = 'causal_keywords_entity_ruler'
matcher.addEntityPattern(causalName, patternsCausal)
# matcher(excavator_df['OriginalShorttext'][i])
matcher(doc)
# Out:
# 06-Dec-22 14:15:52 nlp.RuleBasedMatcher INFO     Create instance of RuleBasedMatcher
# L/H BUCKET CYL LEAKING.
# 06-Dec-22 14:15:55 nlp.nlp_utils        INFO     Model: core_web_lg, Language: en
# 06-Dec-22 14:15:55 nlp.nlp_utils        INFO     Available pipelines:pysbdSentenceBoundaries, tok2vec, tagger, parser, attribute_ruler, lemmatizer, mergePhrase, normEntities, initCoref, aliasResolver, coreferee, anaphorCoref, anaphorEntCoref
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Entity Ruler Matches:
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Print Coreference Info:
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher INFO     Start to extract health status
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: OPEN
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET CYL health status: LEAKING
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET TOOTH" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET TOOTH health status: TOOTH
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET TOOTH" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET TOOTH health status: TOOTH
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET CYLINDER" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET CYLINDER health status: CYLINDER
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    LIP health status: TIPS
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  No status identified for "lip" in "Repair RH120 lip at P&H.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    ADAPTOR health status: LOCK
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    lip shroud health status: Refit
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "adapter" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "TOOTH" dep_ is "nmod" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    TOOTH health status: FIT NEW
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "ADAPTOR" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "adaptor" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    lip shroud health status: pin
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "adaptor" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "grease line" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    grease line health status: loose grease line
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket health status: loose grease line
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET TEETH" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET TEETH health status: MISSING
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    ADAPTORS health status: MISSING
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  No status identified for "BUCKET" in "PARTS FOR BUCKET.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    GREASE LINE health status: ON
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket health status: repair
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    lip shroud health status: lost
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    lip health status: GET
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "ADAPTER" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: CHANGEOUT
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    LIP health status: CHANGEOUT
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "bucket roll cylinder" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket roll cylinder health status: cylinder
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket health status: lip
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "lip" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "teeth" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket health status: fit teeth
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "WEAR" dep_ is "xcomp" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    air con. health status: not getting
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "adapter" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET CYL health status: GLAND
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    GLAND SEAL health status: LEAKING
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  No status identified for "wear package" in "repair wear package rhs inside bkt wall.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "adaptor" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    LIP health status: WELD CRACK
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    lip health status: damaged
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "adaptor" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    LIP health status: PIVOT
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  No status identified for "LIP EAR" in "LH LIP EAR CRACKED.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "lip" dep_ is "appos" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "lower wear edge plate" dep_ is "advmod" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "lip shroud" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    lip shroud health status: shroud
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    boom health status: valve
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    adapter health status:
#
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    lip ear health status: repair crack
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    adaptor health status: COMPLETED
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: ROD
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    GLAND SEAL health status: LEAKING
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "grease line" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    grease line health status: Repair broken grease line
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket health status: Repair broken grease line
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "adaptor" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    tooth health status: COMPLETED
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    lip shroud health status: lock
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket clam health status: gard
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket health status: block
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: BROKEN GREASE FITTING
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "bucket tips" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket tips health status: tips
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "grease line" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    grease line health status: Broken grease line
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket health status: Broken grease line
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "adaptor keeper pin" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    adaptor keeper pin health status: pin
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "LUBE FITTING" dep_ is "nmod" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  No status identified for "BUCKET" in "WELD MODS TO BUCKET.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "TOOTH" dep_ is "npadvmod" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "L/ H BUCKET TOOTH" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    L/ H BUCKET TOOTH health status: TOOTH
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET TEETH" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET TEETH health status: TEETH
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET TEETH health status: BROKEN
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    LUBE LINE health status: BUCKET
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: BROKEN GREASE FITTING
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "GREASE LINES" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    GREASE LINES health status: LINES
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET PIN health status: LINES
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "WEAR PLATES" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    WEAR PLATES health status: BUCKET
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: ASSEMBLY
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET CLAM health status: HOSE
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: PINS
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET CLAM health status: ACTION
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  No status identified for "BUCKET" in "REPAIR SHD23 SPARE BUCKET.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "TOOTH" dep_ is "npadvmod" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: NOT CO
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    HOSE health status: BUCKET
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET CLAM" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET CLAM health status: CLAM
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: REPAIR
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET CLAM PIPE" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET CLAM PIPE health status: PIPE
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: CRACKS
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: CROWD
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "HOSE" dep_ is "nmod" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET PIN health status: COMING
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "bucket tooth" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket tooth health status: tooth
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    bucket teeth health status: worn
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    GREASE LINE health status: ON
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  No status identified for "BOOM" in "CRACK REPAIRS ON BOOM,STICK,BUCKET.."
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  No status identified for "BOOM" in "CRACK REPAIRS ON BOOM,STICK,BUCKET.."
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    GREASE LINE health status: ON
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "GREASE LINE" dep_ is "nmod" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET" dep_ is "npadvmod" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: BROKEN
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    GREASE LINE health status: ON
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: ASSEMBLY
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    GREASE LINE health status: BROKEN
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "HYDRAULIC OIL HOSE" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    HYDRAULIC OIL HOSE health status: HYDRAULIC OIL HOSE
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: HYDRAULIC OIL HOSE
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET TEETH" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET TEETH health status: TEETH
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  No status identified for "BUCKET CLAM" in "STEEL TUBE ON BUCKET CLAM BROKEN.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET CROWD CYLINDER health status: LEAKING
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET" dep_ is "nmod" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "bucket" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET WEAR PLATES" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET WEAR PLATES health status: PLATES
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET TOOTH" dep_ is "dep" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET TOOTH health status: BROKEN
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  No status identified for "GREASE LINE" in "GREASE LINE ON LHS OF BUCKET BROKEN.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET TOOTH health status: FALLEN
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET HOSE" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# [('BUCKET', 'excavator_component', 'SSC'), ('BUCKET CYL', 'excavator_component', 'SSC'), ('BUCKET', 'excavator_component', 'SSC'), ('BUCKET TOOTH', 'excavator_component', 'SSC'), ('BUCKET TOOTH', 'excavator_component', 'SSC'), ('BUCKET CYLINDER', 'excavator_component', 'SSC'), ('BUCKET TEETH', 'excavator_component', 'SSC'), ('LIP', 'excavator_component', 'SSC'), ('LIP', 'excavator_component', 'SSC'), ('lip', 'excavator_component', 'SSC'), ('BUCKET TEETH', 'excavator_component', 'SSC'), ('lip', 'excavator_component', 'SSC'), ('tip', 'excavator_component', 'SSC'), ('tip', 'excavator_component', 'SSC'), ('adaptor', 'excavator_component', 'SSC'), ('lip shrouds', 'excavator_component', 'SSC'), ('BUCKET', 'excavator_component', 'SSC'), ('ADAPTOR', 'excavator_component', 'SSC'), ('lip shroud', 'excavator_component', 'SSC'), ('adapter', 'excavator_component', 'SSC'), ('tooth', 'excavator_component', 'SSC'), ('TOOTH', 'excavator_component', 'SSC'), ('wear package', 'excavator_component', 'SSC'), ('ADAPTOR', 'excavator_component', 'SSC'), ('TOOTH', 'excavator_component', 'SSC'), ('adaptor', 'excavator_component', 'SSC'), ('tooth', 'excavator_component', 'SSC'), ('lip shroud', 'excavator_component', 'SSC'), ('pin', 'excavator_component', 'SSC'), ('adaptors', 'excavator_component', 'SSC'), ('adaptor pins', 'excavator_component', 'SSC'), ('BUCKET CYLINDER GREASE LINE', 'excavator_component', 'SSC'), ('adaptor', 'excavator_component', 'SSC'), ('tip', 'excavator_component', 'SSC'), ('grease line', 'excavator_component', 'SSC'), ('bucket', 'excavator_component', 'SSC'), ('BUCKET TEETH', 'excavator_component', 'SSC'), ('ADAPTORS', 'excavator_component', 'SSC'), ('adaptor', 'excavator_component', 'SSC'), ('BUCKET', 'excavator_component', 'SSC'), ('adaptors', 'excavator_component', 'SSC'), ('bucket tip', 'excavator_component', 'SSC'), ('pins', 'excavator_component', 'SSC'), ('TOOTH', 'excavator_component', 'SSC'), ('ADAPTOR', 'excavator_component', 'SSC'), ('GREASE LINE', 'excavator_component', 'SSC'), ('BUCKET', 'excavator_component', 'SSC'), ('bucket', 'excavator_component', 'SSC'), ('adaptors', 'excavator_component', 'SSC'), ('lip shroud', 'excavator_component', 'SSC'), ('lip', 'excavator_component', 'SSC'), ('ADAPTER', 'excavator_component', 'SSC'), ('adapter pin', 'excavator_component', 'SSC'), ('BUCKET', 'excavator_component', 'SSC'), ('LIP', 'excavator_component', 'SSC'), ('bucket roll cylinder', 'excavator_component', 'SSC'), ('bucket', 'excavator_component', 'SSC'), ('lip', 'excavator_component', 'SSC'), ('teeth', 'excavator_component', 'SSC'), ('bucket', 'excavator_component', 'SSC'), ('WEAR', 'excavator_component', 'SSC'), ('air con.', 'excavator_component', 'SSC'), ('adapter', 'excavator_component', 'SSC'), ('tooth', 'excavator_component', 'SSC'), ('pins', 'excavator_component', 'SSC'), ('BUCKET CYL', 'excavator_component', 'SSC'), ('GLAND SEAL', 'excavator_component', 'SSC'), ('MISSING BUCKET TOOTH', 'excavator_component', ''), ('wear package', 'excavator_component', 'SSC'), ('tip', 'excavator_component', 'SSC'), ('adaptor', 'excavator_component', 'SSC'), ('tip', 'excavator_component', 'SSC'), ('lip shroud', 'excavator_component', 'SSC'), ('LIP', 'excavator_component', 'SSC'), ('tip', 'excavator_component', 'SSC'), ('lip', 'excavator_component', 'SSC'), ('adaptor', 'excavator_component', 'SSC'), ('stick', 'excavator_component', 'SSC'), ('bucket hose', 'excavator_component', 'SSC'), ('LIP', 'excavator_component', 'SSC'), ('GREASE LINES', 'excavator_component', 'SSC'), ('LIP EAR', 'excavator_component', 'SSC'), ('bucket clam', 'excavator_component', 'SSC'), ('lip', 'excavator_component', 'SSC'), ('tips', 'excavator_component', 'SSC'), ('adapter', 'excavator_component', 'SSC'), ('tip', 'excavator_component', 'SSC'), ('lower wear edge plate', 'excavator_component', 'SSC'), ('tooth', 'excavator_component', 'SSC'), ('lip shroud', 'excavator_component', 'SSC'), ('tooth', 'excavator_component', 'SSC'), ('adaptor', 'excavator_component', 'SS ...
# 0: TOOTH(19), TOOTH(24); 1: TOOTH(111), TOOTH(124); 2: REPAIR(705), REPAIR(713); 3: HOSE(760), HOSE(767); 4: TOOTH(1072), TOOTH(1089); 5: TOOTH(1119), TOOTH(1129); 6: TOOTH(1152), TOOTH(1166); 7: REPAIR(1172), Offsite Repair(1178)
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET HOSE health status: HOSE
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET TEETH health status: BROKEN
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  No status identified for "BUCKET" in "CRACKS UNDER HEEL OF BUCKET.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET CLAM CYLINDER" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET CLAM CYLINDER health status: CYLINDER
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET TOOTH health status: @R10
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher WARNING  Entity "BUCKET WEAR PLATES" dep_ is "ROOT" is not among valid list "[nsubj, nsubjpass, pobj, dobj, compound]"
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET WEAR PLATES health status: PLATES
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    BUCKET health status: CRACKS
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher INFO     End of health status extraction!
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher INFO     Start to extract causal relation using OPM model information
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET CYL]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET CYLINDER]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[LIP]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[LIP]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tip, adaptor]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip shrouds]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[ADAPTOR]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip shroud]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adapter, tooth]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[TOOTH]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[wear package]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[ADAPTOR, TOOTH]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Entity "([CHANGE, ADAPTOR, TOOTH])" is identified in "CHANGE ADAPTOR AND TOOTH.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptor, tooth]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip shroud], [pin]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptors]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Entity "([adaptors, as])" is identified in "Replace adaptors as required.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptor pins]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET CYLINDER GREASE LINE]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptor, tip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[grease line], [bucket]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH], [ADAPTORS]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptor]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptors]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket tip, pins]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[TOOTH, ADAPTOR]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINE], [BUCKET]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptors]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip shroud]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[ADAPTER]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adapter pin]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET], [LIP]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket roll cylinder]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Entity "([Change, bucket roll cylinder])" is identified in "Change LH bucket roll cylinder.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket], [lip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Sentence contains causal keywords: [Change].
#  Change bucket lip..
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Causal Info: [Change, bucket, [lip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    No causal/effect entities exist in "Change bucket lip.."
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[teeth], [bucket]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[WEAR]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[air con.]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adapter, tooth, pins]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET CYL], [GLAND SEAL]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[wear package]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptor, tip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip shroud]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[LIP]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Entity "([change, damaged, lip])" is identified in "change out damaged lip.
# "
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptor]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[stick], [bucket hose]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[LIP], [GREASE LINES]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[LIP EAR]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket clam], [lip]]
# 06-Dec-22 14:15:55 nlp.RuleBasedMatcher DEBUG    Sentence contains causal keywords: [Change].
#  Change out bucket clam (lip).
#
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Causal Info: [[('conjecture', True), Change], bucket clam, lip]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher WARNING  Issue found: 'cause list': None, and 'effect list': [[bucket clam], [lip]] were identified in sentence 'Change out bucket clam (lip).
# '
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tips]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adapter, tip]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lower wear edge plate]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tooth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip shroud]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tooth, adaptor]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[boom], [adapter]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tooth, adaptor]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip ear]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip shroud]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tooth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptor]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[teeth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tip, pin]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[grease hose bucket pin]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET], [GLAND SEAL]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[grease line], [bucket]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptor, tooth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tooth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[lip shroud]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket clam]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[grease line], [bucket]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tooth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket lube fittings]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE FITTING], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tooth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket tips]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket tip]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[LIP SHROUD]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[tooth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[grease line], [bucket]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[adaptor keeper pin]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Entity "([DAMAGED, BUCKET])" is identified in "REPAIR DAMAGED BUCKET.
# "
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[LUBE FITTING], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[L/ H BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Entity "([CHANGE, BUCKET TEETH])" is identified in "CHANGE BUCKET TEETH.."
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET PIN]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[LUBE LINE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE FITTING], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINES], [BUCKET PIN]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET PIN]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[WEAR PLATES], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET CLAM], [HOSE]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BOOM], [BUCKET HOSE]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINES], [BUCKET], [PINS]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINES], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET CLAM]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Entity "([CHANGE, TOOTH])" is identified in "CHANGE OUT 1 X BROKEN TOOTH.
# "
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[Tips], [teeth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[HOSE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET CLAM]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET CLAM PIPE]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[HOSE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[STICK]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET], [HOSE]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET GREASE LINE]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Entity "([CHANGE, BUCKET TEETH])" is identified in "CHANGE OUT BUCKET TEETH.
# "
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET PIN]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket tooth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket teeth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BOOM, STICK, BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[HYDRAULIC OIL HOSE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET CLAM]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET CROWD CYLINDER]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET], [HOSE]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET WEAR PLATES]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[GREASE LINE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET HOSE]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TEETH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET CLAM CYLINDER]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[LUBE HOSE], [BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[bucket teeth]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Entity "([Change, bucket teeth])" is identified in "Change out bucket teeth.."
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET WEAR PLATES]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher DEBUG    Conjuncts pairs: [[BUCKET TOOTH]]
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher INFO     End of causal relation extraction!
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher INFO     Start to use general extraction method to extract causal relation
# 06-Dec-22 14:15:56 nlp.RuleBasedMatcher INFO     End of causal relation extraction using general extraction method!
# Identified Cause-Effect Pairs:
